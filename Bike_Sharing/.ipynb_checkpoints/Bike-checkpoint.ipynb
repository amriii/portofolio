# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
# datetime      10886 non-null object
# season        10886 non-null int64
# holiday       10886 non-null int64
# workingday    10886 non-null int64
# weather       10886 non-null int64
# temp          10886 non-null float64
# atemp         10886 non-null float64
# humidity      10886 non-null int64
# windspeed     10886 non-null float64
# casual        10886 non-null int64
# registered    10886 non-null int64
# count         10886 non-null int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.6+ KB

# %%
df["hour"] = [t.hour for t in pd.DatetimeIndex(df.datetime)]
df["day"] = [t.dayofweek for t in pd.DatetimeIndex(df.datetime)]
# df["week_of_year"] = [t.weekofyear for t in pd.DatetimeIndex(df.datetime)]
df["month"] = [t.month for t in pd.DatetimeIndex(df.datetime)]
df['year'] = [t.year for t in pd.DatetimeIndex(df.datetime)]
df['year'] = df['year'].map({2011:0, 2012:1})
df.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  hour  day  month  year
# 0        81        0.0       3          13     16     0    5      1     0
# 1        80        0.0       8          32     40     1    5      1     0
# 2        80        0.0       5          27     32     2    5      1     0
# 3        75        0.0       3          10     13     3    5      1     0
# 4        75        0.0       0           1      1     4    5      1     0

# %%
sns.catplot(x='hour',y='registered', data=df, kind='bar', height=5, aspect=2.5, estimator=np.mean)
plt.show()

# %%
sns.catplot(x='day',y='registered', data=df, kind='bar', height=5, aspect=2.5, estimator=np.mean)
plt.show()

# %%
sns.catplot(x='month',y='registered', data=df, kind='bar', height=5, aspect=2.5, estimator=np.mean)
plt.show()

# %%
sns.catplot(x='season',y='registered', data=df, kind='bar', height=5, aspect=2.5, estimator=np.mean)
plt.show()

# %%
sns.catplot(x='weather',y='registered', data=df, kind='bar', height=5, aspect=2.5, estimator=np.mean)
plt.show()

# %%
df.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  hour  day  month  year
# 0        81        0.0       3          13     16     0    5      1     0
# 1        80        0.0       8          32     40     1    5      1     0
# 2        80        0.0       5          27     32     2    5      1     0
# 3        75        0.0       3          10     13     3    5      1     0
# 4        75        0.0       0           1      1     4    5      1     0

# %%
df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {dtype('int64'): Index(['season', 'holiday', 'workingday', 'weather', 'humidity', 'casual',
#         'registered', 'count', 'hour', 'day', 'month', 'year'],
#        dtype='object'),
#  dtype('float64'): Index(['temp', 'atemp', 'windspeed'], dtype='object'),
#  dtype('O'): Index(['datetime'], dtype='object')}

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_log_error,mean_squared_error, r2_score,mean_absolute_error

# %%
X_train,X_test,y_train,y_test=train_test_split(df.drop(['registered', 'casual', 'count','datetime'],axis=1),df['count'],test_size=0.25,shuffle=False)

# %%
rfr = RandomForestRegressor(n_estimators=1000, criterion='mse', n_jobs=-1)
rfr.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=-1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
predictions = rfr.predict(X_test)

# %%
def print_score(true, prediction):
    print('R2 Score: ',r2_score(true, prediction))
    print('Mean Absoulte Error: ',mean_absolute_error(true, prediction))
    print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(true, prediction)))
    print('Root Mean Squared Log Error: ',np.sqrt(mean_squared_log_error(true, prediction)))
    fig = plt.figure(figsize=(10,8))
    print(sns.distplot(true-prediction, kde=False))
    plt.show()

# %%
print_score(y_test, predictions)
# Out:
# R2 Score:  0.8777333303538137
# Mean Absoulte Error:  47.70576230712712
# Root Mean Squared Error:  75.6350219437071
# Root Mean Squared Log Error:  0.33842149368798424
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
sns.jointplot(y_test, predictions, kind='scatter')
plt.show()

# %%
def point_met(cols):
    act = cols.Actual
    pred = cols.Predicted
    
    if np.abs(act-pred) <= act*0.25:
        return 1
    else:
        return 0

# %%
result_comparison = pd.concat([y_test,pd.Series(predictions, index=y_test.index)], axis=1)
result_comparison.columns = ['Actual', 'Predicted']
result_comparison['Percent'] = np.abs(result_comparison.Actual - result_comparison.Predicted)/result_comparison.Actual*100

# %%
result_comparison['Under20'] = result_comparison.apply(point_met, axis=1)
result_comparison.Under20.mean()
# Out:
# 0.6612784717119765

# %%
result_comparison
# Out:
#        Actual  Predicted    Percent  Under20
# 8164      420    453.520   7.980952        1
# 8165      444    455.830   2.664414        1
# 8166      345    473.310  37.191304        0
# 8167      313    540.720  72.753994        0
# 8168      413    479.880  16.193705        1
# 8169      370    467.100  26.243243        0
# 8170      382    393.540   3.020942        1
# 8171      332    350.090   5.448795        1
# 8172      258    275.540   6.798450        1
# 8173      151    220.170  45.807947        0
# 8174      110     89.480  18.654545        1
# 8175       43     36.365  15.430233        1
# 8176       17     15.320   9.882353        1
# 8177       15     11.150  25.666667        0
# 8178        5      7.220  44.400000        0
# 8179       12      6.850  42.916667        0
# 8180       40     32.480  18.800000        1
# 8181      136    146.570   7.772059        1
# 8182      398    494.620  24.276382        1
# 8183      568    649.910  14.420775        1
# 8184      295    310.540   5.267797        1
# 8185      174    180.370   3.660920        1
# 8186      201    227.390  13.129353        1
# 8187      257    269.925   5.029183        1
# 8188      236    271.865  15.197034        1
# 8189      230    266.505  15.871739        1
# 8190      234    270.275  15.502137        1
# 8191      365    401.880  10.104110        1
# 8192      747    784.185   4.977912        1
# 8193      730    793.270   8.667123        1
# ...       ...        ...        ...      ...
# 10856     525    413.610  21.217143        1
# 10857     353    339.220   3.903683        1
# 10858     268    240.860  10.126866        1
# 10859     168    156.080   7.095238        1
# 10860     132    124.210   5.901515        1
# 10861      81     62.720  22.567901        1
# 10862      41     24.900  39.268293        0
# 10863      15     12.085  19.433333        1
# 10864       3      3.940  31.333333        0
# 10865       5      3.755  24.900000        1
# 10866       7      3.720  46.857143        0
# 10867      31     25.780  16.838710        1
# 10868     112     87.660  21.732143        1
# 10869     363    330.680   8.903581        1
# 10870     678    486.370  28.264012        0
# 10871     317    333.370   5.164038        1
# 10872     164    173.340   5.695122        1
# 10873     200    187.600   6.200000        1
# 10874     236    195.230  17.275424        1
# 10875     213    229.800   7.887324        1
# 10876     218    226.450   3.876147        1
# 10877     237    218.660   7.738397        1
# 10878     334    279.710  16.254491        1
# 10879     562    413.015  26.509786        0
# 10880     569    389.200  31.599297        0
# 10881     336    323.020   3.863095        1
# 10882     241    237.030   1.647303        1
# 10883     168    167.430   0.339286        1
# 10884     129    130.020   0.790698        1
# 10885      88     60.760  30.954545        0
#
# [2722 rows x 4 columns]
