# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test_answers.csv')

# %%
train.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
test.set_index('Unnamed: 0', inplace=True)
test.head()
# Out:
#                        datetime  season  holiday  workingday  weather   temp  \
# Unnamed: 0
# 0           2011-01-20 00:00:00       1        0           1        1  10.66
# 1           2011-01-20 01:00:00       1        0           1        1  10.66
# 2           2011-01-20 02:00:00       1        0           1        1  10.66
# 3           2011-01-20 03:00:00       1        0           1        1  10.66
# 4           2011-01-20 04:00:00       1        0           1        1  10.66
#
#              atemp  humidity  windspeed  casual  registered  cnt
# Unnamed: 0
# 0           11.365        56    26.0027       3          13   16
# 1           13.635        56     0.0000       8          32   40
# 2           13.635        56     0.0000       5          27   32
# 3           12.880        56    11.0014       3          10   13
# 4           12.880        56    11.0014       0           1    1

# %%
train.columns = ['datetime', 'season', 'holiday', 'workingday', 'weather', 'temperature',
       'feel_temperature', 'humidity', 'windspeed', 'casual', 'registered', 'total']

# %%
test.columns = train.columns

# %%
train.head()
# Out:
#               datetime  season  holiday  workingday  weather  temperature  \
# 0  2011-01-01 00:00:00       1        0           0        1         9.84
# 1  2011-01-01 01:00:00       1        0           0        1         9.02
# 2  2011-01-01 02:00:00       1        0           0        1         9.02
# 3  2011-01-01 03:00:00       1        0           0        1         9.84
# 4  2011-01-01 04:00:00       1        0           0        1         9.84
#
#    feel_temperature  humidity  windspeed  casual  registered  total
# 0            14.395        81        0.0       3          13     16
# 1            13.635        80        0.0       8          32     40
# 2            13.635        80        0.0       5          27     32
# 3            14.395        75        0.0       3          10     13
# 4            14.395        75        0.0       0           1      1

# %%
test.head()
# Out:
#                        datetime  season  holiday  workingday  weather  \
# Unnamed: 0
# 0           2011-01-20 00:00:00       1        0           1        1
# 1           2011-01-20 01:00:00       1        0           1        1
# 2           2011-01-20 02:00:00       1        0           1        1
# 3           2011-01-20 03:00:00       1        0           1        1
# 4           2011-01-20 04:00:00       1        0           1        1
#
#             temperature  feel_temperature  humidity  windspeed  casual  \
# Unnamed: 0
# 0                 10.66            11.365        56    26.0027       3
# 1                 10.66            13.635        56     0.0000       8
# 2                 10.66            13.635        56     0.0000       5
# 3                 10.66            12.880        56    11.0014       3
# 4                 10.66            12.880        56    11.0014       0
#
#             registered  total
# Unnamed: 0
# 0                   13     16
# ...

# %%
df = pd.concat([train, test])

# %%
df = df.sort_values('datetime').reset_index()

# %%
df.head()
# Out:
#    index             datetime  season  holiday  workingday  weather  \
# 0      0  2011-01-01 00:00:00       1        0           0        1
# 1      1  2011-01-01 01:00:00       1        0           0        1
# 2      2  2011-01-01 02:00:00       1        0           0        1
# 3      3  2011-01-01 03:00:00       1        0           0        1
# 4      4  2011-01-01 04:00:00       1        0           0        1
#
#    temperature  feel_temperature  humidity  windspeed  casual  registered  \
# 0         9.84            14.395        81        0.0       3          13
# 1         9.02            13.635        80        0.0       8          32
# 2         9.02            13.635        80        0.0       5          27
# 3         9.84            14.395        75        0.0       3          10
# 4         9.84            14.395        75        0.0       0           1
#
#    total
# 0     16
# 1     40
# 2     32
# 3     13
# 4      1

# %%
df["hour"] = [t.hour for t in pd.DatetimeIndex(df.datetime)]
df["day"] = [t.dayofweek for t in pd.DatetimeIndex(df.datetime)]
df["month"] = [t.month for t in pd.DatetimeIndex(df.datetime)]
df['year'] = [t.year for t in pd.DatetimeIndex(df.datetime)]
df.head()
# Out:
#    index             datetime  season  holiday  workingday  weather  \
# 0      0  2011-01-01 00:00:00       1        0           0        1
# 1      1  2011-01-01 01:00:00       1        0           0        1
# 2      2  2011-01-01 02:00:00       1        0           0        1
# 3      3  2011-01-01 03:00:00       1        0           0        1
# 4      4  2011-01-01 04:00:00       1        0           0        1
#
#    temperature  feel_temperature  humidity  windspeed  casual  registered  \
# 0         9.84            14.395        81        0.0       3          13
# 1         9.02            13.635        80        0.0       8          32
# 2         9.02            13.635        80        0.0       5          27
# 3         9.84            14.395        75        0.0       3          10
# 4         9.84            14.395        75        0.0       0           1
#
#    total  hour  day  month  year
# 0     16     0    5      1  2011
# 1     40     1    5      1  2011
# ...

# %%
df.columns
# Out:
# Index(['index', 'datetime', 'season', 'holiday', 'workingday', 'weather',
#        'temperature', 'feel_temperature', 'humidity', 'windspeed', 'casual',
#        'registered', 'total', 'hour', 'day', 'month', 'year'],
#       dtype='object')

# %%
df = df[['datetime', 'year', 'month','day', 'hour','season', 'holiday', 'workingday', 'weather', 'temperature',
       'feel_temperature', 'humidity', 'windspeed',   'casual', 'registered',
       'total']]

# %%
df.head()
# Out:
#               datetime  year  month  day  hour  season  holiday  workingday  \
# 0  2011-01-01 00:00:00  2011      1    5     0       1        0           0
# 1  2011-01-01 01:00:00  2011      1    5     1       1        0           0
# 2  2011-01-01 02:00:00  2011      1    5     2       1        0           0
# 3  2011-01-01 03:00:00  2011      1    5     3       1        0           0
# 4  2011-01-01 04:00:00  2011      1    5     4       1        0           0
#
#    weather  temperature  feel_temperature  humidity  windspeed  casual  \
# 0        1         9.84            14.395        81        0.0       3
# 1        1         9.02            13.635        80        0.0       8
# 2        1         9.02            13.635        80        0.0       5
# 3        1         9.84            14.395        75        0.0       3
# 4        1         9.84            14.395        75        0.0       0
#
#    registered  total
# 0          13     16
# 1          32     40
# ...

# %%
# df.to_csv('bike_demand.csv')

# %%
df[df.datetime > "2012-10-28 00:00:00"]
# Out:
#                   datetime  year  month  day  hour  season  holiday  \
# 15860  2012-10-28 01:00:00  2012     10    6     1       4        0
# 15861  2012-10-28 02:00:00  2012     10    6     2       4        0
# 15862  2012-10-28 03:00:00  2012     10    6     3       4        0
# 15863  2012-10-28 04:00:00  2012     10    6     4       4        0
# 15864  2012-10-28 05:00:00  2012     10    6     5       4        0
# 15865  2012-10-28 06:00:00  2012     10    6     6       4        0
# 15866  2012-10-28 07:00:00  2012     10    6     7       4        0
# 15867  2012-10-28 08:00:00  2012     10    6     8       4        0
# 15868  2012-10-28 09:00:00  2012     10    6     9       4        0
# 15869  2012-10-28 10:00:00  2012     10    6    10       4        0
# 15870  2012-10-28 11:00:00  2012     10    6    11       4        0
# 15871  2012-10-28 12:00:00  2012     10    6    12       4        0
# 15872  2012-10-28 13:00:00  2012     10    6    13       4        0
# ...

# %%
df_true =  pd.read_csv('bike_sharing_hour.csv')

# %%
compare = pd.concat([df[['datetime','total']],df_true.cnt], axis=1)
compare[compare.total != compare.cnt]
# Out:
# Empty DataFrame
# Columns: [datetime, total, cnt]
# Index: []

# %%
# df['total'] = df_true['cnt']
